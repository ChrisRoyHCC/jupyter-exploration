# %% [markdown]
# This is my first Markdown cell in Jupyter, let alone my first experience in Jupyter as a whole.
# I first saw Jupyter and Spyder when I was looking into Pycharm after stumbling upon Anaconda, I didn't understand it then,
# and I don't understand it now, so I'm going to go skim some of the documentation you've left me.

# %%
print("Hello, World")
# Out:
# Hello, World
